# %%
import pymysql
import paramiko
import pandas as pd
from paramiko import SSHClient
from sshtunnel import SSHTunnelForwarder
from os.path import expanduser
import sqlalchemy

# %%
sql_hostname = '127.0.0.1'
sql_username = 'phpmyadmin'
sql_password = '8j3h2o'
sql_main_database = 'bi_nuclio'
sql_port = 3306
ssh_Host = '34.74.105.225'
ssh_user = 'charles'
ssh_pass='charles1234kotzerlinux'
ssh_port = 22
sql_ip = '1.1.1.1.1'

# %%
def query(query):
    with SSHTunnelForwarder(
            (ssh_Host, ssh_port),
            ssh_username=ssh_user,
            ssh_password=ssh_pass,
            remote_bind_address=(sql_hostname, sql_port)) as tunnel:
        conn = pymysql.connect(host='127.0.0.1', user=sql_username,
                passwd=sql_password, db=sql_main_database,
                port=tunnel.local_bind_port)
        query = '''SHOW TABLES;'''
        data = pd.read_sql_query(query, conn)
        conn.close()

# %%
query('SELECT * FROM MATRICULAS')

# %%
data

# %%
with SSHTunnelForwarder(
        (ssh_Host, ssh_port),
        ssh_username=ssh_user,
        ssh_password=ssh_pass,
        remote_bind_address=(sql_hostname, sql_port)) as tunnel:
    conn = pymysql.connect(host='127.0.0.1', user=sql_username,
            passwd=sql_password, db=sql_main_database,
            port=tunnel.local_bind_port)
    cursor = conn.cursor()
    cursor.excute('SELECT * FROM MATRICULAS')
    result = cursor.fetchall()
    cursor.close()
    conn.close()
    
print(result)

# %%
import pymysql
cnx = pymysql.connect(db     = 'database_name', 
                  user   = 'database_username', 
                  passwd = 'database_password', 
                  host   = '127.0.0.1', 
                  port   = 3307,
                  ) 
cursor = cnx.cursor()
cursor.execute("SELECT NOW()")
result = cursor.fetchall()
cursor.close()
cnx.close()

print(result)

# %%
data
# Out:
#    Tables_in_bi_nuclio
# 0        analisispagos
# 1           backupbank
# 2           bankdetail
# 3              canales
# 4          comerciales
# 5                 cost
# 6         costemensual
# 7               cuotas
# 8          fechaspagos
# 9                  kpi
# 10          matriculas
# 11     program_details
# 12           programas
# 13            tipopago
# 14               users

# %%
#def query(query):
with SSHTunnelForwarder(
        (ssh_Host, ssh_port),
        ssh_username=ssh_user,
        ssh_password=ssh_pass,
        remote_bind_address=(sql_hostname, sql_port)) as tunnel:
    cadena_conexion='mysql+mysqlconnector://phpmyadmin:8j3h2o@localhost/bi_nuclio'
    engine = sqlalchemy.create_engine(cadena_conexion)
    data = pd.read_sql("SELECT * FROM MATRICULAS", con=engine)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     215         try:
# --> 216             self._cmysql.connect(**cnx_kwargs)
#     217         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Access denied for user 'phpmyadmin'@'localhost' (using password: YES)
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# ...

# %%
with SSHTunnelForwarder(
        (ssh_Host, ssh_port),
        ssh_username=ssh_user,
        ssh_password=ssh_pass,
        remote_bind_address=(sql_hostname, sql_port)) as tunnel:
    cadena_conexion='mysql+mysqlconnector://phpmyadmin:8j3h2o@localhost/bi_nuclio'
    engine = sqlalchemy.create_engine(cadena_conexion)
    engine.execute('SHOW TABLES').fetchall()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     215         try:
# --> 216             self._cmysql.connect(**cnx_kwargs)
#     217         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Access denied for user 'phpmyadmin'@'localhost' (using password: YES)
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# ...

# %%
query("SHOW TABLES")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     215         try:
# --> 216             self._cmysql.connect(**cnx_kwargs)
#     217         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Access denied for user 'phpmyadmin'@'localhost' (using password: YES)
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# ...

# %%
ssh -i key.pem -fN -L 3307:localhost:3306 username@site_or_ip_address_hosting_the_database
# Out:
#   File "<ipython-input-6-5a50c51b83b4>", line 1
#     ssh -i key.pem -fN -L 3307:localhost:3306 username@site_or_ip_address_hosting_the_database
#              ^
# SyntaxError: invalid syntax

# %%
def query(q):
     with SSHTunnelForwarder(
          (ssh_Host, ssh_port),
          ssh_username=ssh_user,
          ssh_password=ssh_pass,
          remote_bind_address=(sql_hostname, sql_port)
     ) as server:
          conn = pymysql.connect(host=sql_hostname,
          port=server.local_bind_port,
          user=sql_username,
          passwd=sql_password,
          db=sql_main_database)
          return pd.read_sql_query(q, conn)
          conn.close()

# %%
df = query('select * from matricula')

# %%
sql_hostname = '127.0.0.1'
sql_username = 'phpmyadmin'
sql_password = '8j3h2o'
sql_main_database = 'bi_nuclio'
sql_port = 3306
ssh_Host = '34.74.105.225'
ssh_user = 'charles'
ssh_pass='charles1234kotzerlinux'
ssh_port = 22
sql_ip = '1.1.1.1.1'
